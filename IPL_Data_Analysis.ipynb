# %%
#Loading the requried libraries
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
#loading the ipl matches dataset
df = pd.read_csv("IPL_Matches.csv")

# %%
#having a glance at the first five records of the dataset
df.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
#lookin at the number of rows and columns in the dataset
df.shape
# Out:
# (1095, 20)

# %%
#Getting the most man of the matches awards
df['player_of_match'].value_counts()
# Out:
# player_of_match
# AB de Villiers       25
# CH Gayle             22
# RG Sharma            19
# DA Warner            18
# V Kohli              18
#                      ..
# NV Ojha               1
# KV Sharma             1
# Washington Sundar     1
# PD Collingwood        1
# Shahbaz Ahmed         1
# Name: count, Length: 291, dtype: int64

# %%
#Getting the top 10 players with most man of the matches awards
df['player_of_match'].value_counts()[0:10]
# Out:
# player_of_match
# AB de Villiers    25
# CH Gayle          22
# RG Sharma         19
# DA Warner         18
# V Kohli           18
# MS Dhoni          17
# SR Watson         16
# YK Pathan         16
# RA Jadeja         16
# AD Russell        15
# Name: count, dtype: int64

# %%
#Getting the top 5 players with most man of the matches awards
df['player_of_match'].value_counts()[0:5]
# Out:
# player_of_match
# AB de Villiers    25
# CH Gayle          22
# RG Sharma         19
# DA Warner         18
# V Kohli           18
# Name: count, dtype: int64

# %%
list(df['player_of_match'].value_counts()[0:5].keys())
# Out:
# ['AB de Villiers', 'CH Gayle', 'RG Sharma', 'DA Warner', 'V Kohli']

# %%
#making a bar plot for the top 5 players with most of the man of the matches
plt.figure(figsize=(8,5))
plt.bar(list(df['player_of_match'].value_counts()[0:5].keys()),list(df['player_of_match'].value_counts()[0:5]),color="b")
plt.show()

# %%
#Getting the frequency of result column
df['result'].value_counts()
# Out:
# result
# wickets      578
# runs         498
# tie           14
# no result      5
# Name: count, dtype: int64

# %%
#finding out the number of toss wins w.r.t each team
df['toss_winner'].value_counts()
# Out:
# toss_winner
# Mumbai Indians                 143
# Kolkata Knight Riders          122
# Chennai Super Kings            122
# Rajasthan Royals               120
# Royal Challengers Bangalore    113
# Sunrisers Hyderabad             88
# Kings XI Punjab                 85
# Delhi Daredevils                80
# Delhi Capitals                  50
# Deccan Chargers                 43
# Punjab Kings                    24
# Gujarat Titans                  22
# Pune Warriors                   20
# Lucknow Super Giants            19
# Gujarat Lions                   15
# Kochi Tuskers Kerala             8
# Royal Challengers Bengaluru      8
# Rising Pune Supergiants          7
# Rising Pune Supergiant           6
# Name: count, dtype: int64

# %%
#finding out the result margin
df['result_margin'].value_counts()
# Out:
# result_margin
# 6.0      131
# 7.0      130
# 5.0      109
# 8.0       85
# 4.0       74
#         ...
# 76.0       1
# 53.0       1
# 105.0      1
# 66.0       1
# 106.0      1
# Name: count, Length: 98, dtype: int64

# %%
deliveries=pd.read_csv("deliveries.csv")

# %%
deliveries.sample(5)
# Out:
#         match_id  inning            batting_team                 bowling_team  \
# 145684   1082630       1     Sunrisers Hyderabad             Delhi Daredevils
# 30228     419119       1          Mumbai Indians  Royal Challengers Bangalore
# 146584   1082634       1  Rising Pune Supergiant          Sunrisers Hyderabad
# 228980   1359487       2   Kolkata Knight Riders               Gujarat Titans
# 136935   1082592       1          Mumbai Indians       Rising Pune Supergiant
#
#         over  ball              batter          bowler   non_striker  \
# 145684    14     5        Yuvraj Singh        A Mishra  MC Henriques
# 30228      0     3       ST Jayasuriya         P Kumar  SR Tendulkar
# 146584     5     7           AM Rahane    MC Henriques     SPD Smith
# 228980     0     2  Rahmanullah Gurbaz  Mohammed Shami  N Jagadeesan
# 136935    14     3          KA Pollard     Imran Tahir        N Rana
#
#         batsman_runs  extra_runs  total_runs extras_type  is_wicket  \
# ...

# %%
#Finding the total runs scored by each team
toatl_runs_scored=deliveries.groupby(by=['batting_team']).sum()[['total_runs']]

# %%
top_10 = toatl_runs_scored.sort_values(by='total_runs',ascending=False).head(10)

# %%
plt.figure(figsize=(10,5))
plt.grid(True)
plt.plot(top_10)
plt.xticks(rotation=40)
plt.xlabel('batting team')
plt.ylabel('total runs')
plt.show()

# %%
#Identify the top 10 highest-scoring batters
total_runs_batsman=deliveries.groupby(by=['batter']).sum()[['batsman_runs']]

# %%
top_10_batsman = total_runs_batsman.sort_values(['batsman_runs'], ascending= False)[:10]

# %%
plt.figure(figsize=(10,5))
plt.grid(True)
plt.bar(top_10_batsman.index, top_10_batsman['batsman_runs'])
plt.xticks(rotation=40)
plt.xlabel('batters')
plt.ylabel('toatl runs')
plt.show()

# %%
#Finding the bowler with most wickets
dismissals= deliveries[deliveries['is_wicket']==1].groupby(by=['bowler']).sum()[['is_wicket']]

# %%
top_10_bowlers = dismissals.sort_values(['is_wicket'],ascending=False)[0:10]

# %%
plt.figure(figsize=(10,5))
plt.grid(True)
plt.bar(top_10_bowlers.index, top_10_bowlers['is_wicket'])
plt.xticks(rotation=40)
plt.xlabel('bowlers')
plt.ylabel('total wickets')
plt.show()

# %%
#determining which over has the highest run rate
over_run_rate= deliveries.groupby(by=['over'])['total_runs'].mean()

# %%
top_10_over=over_run_rate.sort_values(ascending=False)[0:10]

# %%
plt.figure(figsize=(10,5))
plt.grid(True)
#plt.bar(top_10_over.index, top_10_over)
plt.plot(top_10_over)
plt.xlim(20,0)
plt.xticks(rotation=40)
plt.xlabel('overs')
plt.ylabel('Average run rate')
plt.show()

# %%
#Analyze powerplay performance (first 6 overs)
powerplay = deliveries[deliveries['over']<6].groupby(['batting_team']).sum()[['total_runs']]

# %%
plt.figure(figsize=(10,5))
plt.grid(True)
plt.bar(powerplay.index, powerplay['total_runs'],align='edge')
plt.xticks(rotation=40)
plt.xlabel('batting teams')
plt.ylabel('total runs')
plt.show()

# %%
#finding the batsman with the most sixes and fours
max_six_four=deliveries[(deliveries['batsman_runs']==4)|(deliveries['batsman_runs']==6)].groupby(['batter']).sum()[['batsman_runs']]

# %%
max_six_four = max_six_four.sort_values('batsman_runs',ascending=False)[:10]

# %%
plt.figure(figsize=(10,5))
plt.grid(True)
plt.bar(max_six_four.index, max_six_four['batsman_runs'])
plt.xticks(rotation=40)
plt.xlabel('batting teams')
plt.ylabel('total runs')
plt.show()
